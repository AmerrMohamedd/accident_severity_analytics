# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('E:/accident_severity_analytics/data/raw/US_Accidents_March23.csv')
df
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# ...

# %%
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %%
duplicates=df.duplicated(subset=['ID'],keep=False)
print(df[duplicates])
# Out:
# Empty DataFrame
# Columns: [ID, Source, Severity, Start_Time, End_Time, Start_Lat, Start_Lng, End_Lat, End_Lng, Distance(mi), Description, Street, City, County, State, Zipcode, Country, Timezone, Airport_Code, Weather_Timestamp, Temperature(F), Wind_Chill(F), Humidity(%), Pressure(in), Visibility(mi), Wind_Direction, Wind_Speed(mph), Precipitation(in), Weather_Condition, Amenity, Bump, Crossing, Give_Way, Junction, No_Exit, Railway, Roundabout, Station, Stop, Traffic_Calming, Traffic_Signal, Turning_Loop, Sunrise_Sunset, Civil_Twilight, Nautical_Twilight, Astronomical_Twilight]
# Index: []
#
# [0 rows x 46 columns]

# %%
missing_percent = df.isnull().mean() * 100
missing_percent
# Out:
# ID                        0.000000
# Source                    0.000000
# Severity                  0.000000
# Start_Time                0.000000
# End_Time                  0.000000
# Start_Lat                 0.000000
# Start_Lng                 0.000000
# End_Lat                  44.029355
# End_Lng                  44.029355
# Distance(mi)              0.000000
# Description               0.000065
# Street                    0.140637
# City                      0.003274
# County                    0.000000
# State                     0.000000
# Zipcode                   0.024779
# Country                   0.000000
# Timezone                  0.101030
# Airport_Code              0.292881
# Weather_Timestamp         1.555666
# Temperature(F)            2.120143
# Wind_Chill(F)            25.865904
# Humidity(%)               2.253301
# Pressure(in)              1.820288
# Visibility(mi)            2.291524
# Wind_Direction            2.267043
# Wind_Speed(mph)           7.391355
# ...

# %%
df.drop(['End_Lat', 'End_Lng', 'Wind_Chill(F)', 'Precipitation(in)', 'Airport_Code'], axis=1, inplace=True)

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'], errors='coerce') 
df['End_Time'] = pd.to_datetime(df['End_Time'], errors='coerce')

# %%
df['Weather_Timestamp'] = pd.to_datetime(df['Weather_Timestamp'], errors='coerce')

# %%
df['Temperature(F)'] = pd.to_numeric(df['Temperature(F)'], errors='coerce')
df['Wind_Speed(mph)'] = pd.to_numeric(df['Wind_Speed(mph)'], errors='coerce')
df['Severity'] = df['Severity'].astype(int)

# %%
df['Description'] = df['Description'].astype(str)
df['City'] = df['City'].astype(str)
df['Street'] = df['Street'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 41 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             datetime64[ns]
#  4   End_Time               datetime64[ns]
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   Distance(mi)           float64
#  8   Description            object
#  9   Street                 object
#  10  City                   object
#  11  County                 object
#  12  State                  object
#  13  Zipcode                object
#  14  Country                object
#  15  Timezone               object
#  16  Weather_Timestamp      datetime64[ns]
#  17  Temperature(F)         float64
#  18  Humidity(%)            float64
#  19  Pressure(in)           float64
#  20  Visibility(mi)         float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# Source                        0
# Severity                      0
# Start_Time               743166
# End_Time                 743166
# Start_Lat                     0
# Start_Lng                     0
# Distance(mi)                  0
# Description                   0
# Street                        0
# City                          0
# County                        0
# State                         0
# Zipcode                    1915
# Country                       0
# Timezone                   7808
# Weather_Timestamp        120228
# Temperature(F)           163853
# Humidity(%)              174144
# Pressure(in)             140679
# Visibility(mi)           177098
# Wind_Direction           175206
# Wind_Speed(mph)          571233
# Weather_Condition        173459
# Amenity                       0
# Bump                          0
# Crossing                      0
# Give_Way                      0
# Junction                      0
# ...

# %%
df.shape
# Out:
# (7728394, 41)

# %%
df.dropna(subset=['Start_Time', 'End_Time'], inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                            0
# Source                        0
# Severity                      0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# Start_Lng                     0
# Distance(mi)                  0
# Description                   0
# Street                        0
# City                          0
# County                        0
# State                         0
# Zipcode                    1677
# Country                       0
# Timezone                   6785
# Weather_Timestamp        106209
# Temperature(F)           146088
# Humidity(%)              155344
# Pressure(in)             125243
# Visibility(mi)           158101
# Wind_Direction           153449
# Wind_Speed(mph)          549373
# Weather_Condition        155462
# Amenity                       0
# Bump                          0
# Crossing                      0
# Give_Way                      0
# Junction                      0
# ...

# %%
df.dropna(subset=['Wind_Speed(mph)'], inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                           0
# Source                       0
# Severity                     0
# Start_Time                   0
# End_Time                     0
# Start_Lat                    0
# Start_Lng                    0
# Distance(mi)                 0
# Description                  0
# Street                       0
# City                         0
# County                       0
# State                        0
# Zipcode                      0
# Country                      0
# Timezone                     0
# Weather_Timestamp            0
# Temperature(F)           20112
# Humidity(%)              28674
# Pressure(in)              6453
# Visibility(mi)           22186
# Wind_Direction              66
# Wind_Speed(mph)              0
# Weather_Condition        20265
# Amenity                      0
# Bump                         0
# Crossing                     0
# Give_Way                     0
# Junction                     0
# No_Exit                      0
# ...

# %%
df.dropna(subset=['Sunrise_Sunset'], inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                           0
# Source                       0
# Severity                     0
# Start_Time                   0
# End_Time                     0
# Start_Lat                    0
# Start_Lng                    0
# Distance(mi)                 0
# Description                  0
# Street                       0
# City                         0
# County                       0
# State                        0
# Zipcode                      0
# Country                      0
# Timezone                     0
# Weather_Timestamp            0
# Temperature(F)           20025
# Humidity(%)              28543
# Pressure(in)              6393
# Visibility(mi)           22088
# Wind_Direction              66
# Wind_Speed(mph)              0
# Weather_Condition        20176
# Amenity                      0
# Bump                         0
# Crossing                     0
# Give_Way                     0
# Junction                     0
# No_Exit                      0
# ...

# %%
df['Temperature(F)'] = df['Temperature(F)'].fillna(df['Temperature(F)'].mean())
df['Humidity(%)'] = df['Humidity(%)'].fillna(df['Humidity(%)'].mean())
df['Pressure(in)'] = df['Pressure(in)'].fillna(df['Pressure(in)'].mean())
df['Visibility(mi)'] = df['Visibility(mi)'].fillna(df['Visibility(mi)'].mean())

df['Weather_Condition'] = df['Weather_Condition'].fillna('Unknown')
df['Wind_Direction'] = df['Wind_Direction'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# Distance(mi)             0
# Description              0
# Street                   0
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Weather_Timestamp        0
# Temperature(F)           0
# Humidity(%)              0
# Pressure(in)             0
# Visibility(mi)           0
# Wind_Direction           0
# Wind_Speed(mph)          0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# No_Exit                  0
# Railway                  0
# Roundabout               0
# Station                  0
# Stop                     0
# ...

# %%
#Check time
df = df[df['Start_Time'] <= df['End_Time']]

# %%
df.describe()
# Out:
#            Severity                     Start_Time  \
# count  6.420506e+06                        6420506
# mean   2.219504e+00  2020-05-05 17:20:35.822601728
# min    1.000000e+00            2016-01-14 20:18:33
# 25%    2.000000e+00     2018-12-11 09:05:41.500000
# 50%    2.000000e+00            2020-09-30 13:18:00
# 75%    2.000000e+00            2021-11-16 15:33:00
# max    4.000000e+00            2023-03-31 23:30:00
# std    4.926383e-01                            NaN
#
#                             End_Time     Start_Lat     Start_Lng  \
# count                        6420506  6.420506e+06  6.420506e+06
# mean      2020-05-06 00:32:01.554688  3.621068e+01 -9.461266e+01
# min              2016-02-08 06:37:08  2.455480e+01 -1.246238e+02
# 25%    2018-12-11 10:03:57.750000128  3.333643e+01 -1.171521e+02
# 50%       2020-09-30 18:18:23.500000  3.581492e+01 -8.781961e+01
# 75%       2021-11-17 01:56:49.500000  4.013235e+01 -8.040754e+01
# ...

# %%
# Distance(mi) : Max= 441.75
df = df[df['Distance(mi)'] <= 50]

# %%
df.shape
# Out:
# (6419940, 41)

# %%
df.describe()
# Out:
#            Severity                     Start_Time  \
# count  6.419940e+06                        6419940
# mean   2.219467e+00  2020-05-05 17:07:11.518182656
# min    1.000000e+00            2016-01-14 20:18:33
# 25%    2.000000e+00            2018-12-11 08:52:12
# 50%    2.000000e+00     2020-09-30 13:13:23.500000
# 75%    2.000000e+00            2021-11-16 15:28:34
# max    4.000000e+00            2023-03-31 23:30:00
# std    4.925954e-01                            NaN
#
#                             End_Time     Start_Lat     Start_Lng  \
# count                        6419940  6.419940e+06  6.419940e+06
# mean   2020-05-06 00:18:37.848259840  3.621046e+01 -9.461248e+01
# min              2016-02-08 06:37:08  2.455480e+01 -1.246238e+02
# 25%       2018-12-11 09:51:26.500000  3.333624e+01 -1.171523e+02
# 50%              2020-09-30 18:15:07  3.581473e+01 -8.781914e+01
# 75%              2021-11-17 01:20:42  4.013215e+01 -8.040748e+01
# ...

# %%
# Temperature(F) : Min= -89°F
#                  Max= 207°F
df = df[(df['Temperature(F)'] >= -30) & (df['Temperature(F)'] <= 130)]

# %%
df.shape
# Out:
# (6419792, 41)

# %%
df.describe()
# Out:
#            Severity                     Start_Time  \
# count  6.419792e+06                        6419792
# mean   2.219471e+00  2020-05-05 16:49:09.088358144
# min    1.000000e+00            2016-01-14 20:18:33
# 25%    2.000000e+00  2018-12-11 08:48:01.249999872
# 50%    2.000000e+00            2020-09-30 12:58:24
# 75%    2.000000e+00            2021-11-16 15:17:31
# max    4.000000e+00            2023-03-31 23:30:00
# std    4.925915e-01                            NaN
#
#                             End_Time     Start_Lat     Start_Lng  \
# count                        6419792  6.419792e+06  6.419792e+06
# mean   2020-05-06 00:00:35.903968256  3.621052e+01 -9.461261e+01
# min              2016-02-08 06:37:08  2.455480e+01 -1.246238e+02
# 25%       2018-12-11 09:41:59.500000  3.333655e+01 -1.171524e+02
# 50%              2020-09-30 17:59:50  3.581481e+01 -8.781958e+01
# 75%       2021-11-17 00:05:49.500000  4.013215e+01 -8.040743e+01
# ...

# %%
#Wind_Speed(mph) : Max= 1087 mph
df = df[df['Wind_Speed(mph)'] <= 80]

# %%
df.shape
# Out:
# (6419627, 41)

# %%
df.describe()
# Out:
#            Severity                  Start_Time  \
# count  6.419627e+06                     6419627
# mean   2.219469e+00  2020-05-05 16:56:06.570592
# min    1.000000e+00         2016-01-14 20:18:33
# 25%    2.000000e+00         2018-12-11 08:50:55
# 50%    2.000000e+00         2020-09-30 13:07:00
# 75%    2.000000e+00         2021-11-16 15:18:06
# max    4.000000e+00         2023-03-31 23:30:00
# std    4.925911e-01                         NaN
#
#                             End_Time     Start_Lat     Start_Lng  \
# count                        6419627  6.419627e+06  6.419627e+06
# mean   2020-05-06 00:07:33.894485248  3.621053e+01 -9.461248e+01
# min              2016-02-08 06:37:08  2.455480e+01 -1.246238e+02
# 25%       2018-12-11 09:49:54.500000  3.333662e+01 -1.171523e+02
# 50%              2020-09-30 18:07:05  3.581484e+01 -8.781929e+01
# 75%              2021-11-17 00:10:32  4.013217e+01 -8.040739e+01
# max              2023-03-31 23:59:00  4.900220e+01 -6.711317e+01
# ...

# %%
# Visibility(mi) : Max= 140.0
df = df[df['Visibility(mi)'] <= 40]

# %%
df.shape
# Out:
# (6416545, 41)

# %%
df.describe()
# Out:
#            Severity                     Start_Time  \
# count  6.416545e+06                        6416545
# mean   2.219366e+00  2020-05-05 22:27:21.836367104
# min    1.000000e+00            2016-01-14 20:18:33
# 25%    2.000000e+00            2018-12-11 16:19:27
# 50%    2.000000e+00            2020-09-30 19:28:09
# 75%    2.000000e+00            2021-11-16 16:34:00
# max    4.000000e+00            2023-03-31 23:30:00
# std    4.925302e-01                            NaN
#
#                             End_Time     Start_Lat     Start_Lng  \
# count                        6416545  6.416545e+06  6.416545e+06
# mean   2020-05-06 05:38:58.752961792  3.620930e+01 -9.460619e+01
# min              2016-02-08 06:37:08  2.455480e+01 -1.246238e+02
# 25%              2018-12-11 17:13:58  3.333463e+01 -1.171529e+02
# 50%              2020-10-01 01:40:27  3.581206e+01 -8.780687e+01
# 75%              2021-11-17 07:21:51  4.013321e+01 -8.040434e+01
# ...

# %%
summary = df[['Temperature(F)', 'Humidity(%)', 'Wind_Speed(mph)','Visibility(mi)']].agg(['min', 'max'])
summary
# Out:
#      Temperature(F)  Humidity(%)  Wind_Speed(mph)  Visibility(mi)
# min           -30.0          1.0              0.0             0.0
# max           129.2        100.0             79.4            40.0

# %%
#check zeros
cols = ['Temperature(F)', 'Humidity(%)', 'Wind_Speed(mph)', 'Visibility(mi)']

for col in cols:
    total = df.shape[0]
    zeros = (df[col] == 0).sum()
    percent = (zeros / total) * 100
    print(f"{col}: Number of zero values = {zeros} out of {total} ({percent:.2f}%)")
# Out:
# Temperature(F): Number of zero values = 2258 out of 6416545 (0.04%)
# Humidity(%): Number of zero values = 0 out of 6416545 (0.00%)
# Wind_Speed(mph): Number of zero values = 838362 out of 6416545 (13.07%)
# Visibility(mi): Number of zero values = 6425 out of 6416545 (0.10%)

# %%
df['Wind_Speed(mph)'] = df['Wind_Speed(mph)'].replace(0, np.nan)

# %%
df['Wind_Speed(mph)'] = df['Wind_Speed(mph)'].fillna(df['Wind_Speed(mph)'].median())

# %%
df['Wind_Speed(mph)'].dtype
# Out:
# dtype('float64')

# %%
#check zeros
cols = ['Temperature(F)', 'Humidity(%)', 'Wind_Speed(mph)', 'Visibility(mi)']

for col in cols:
    total = df.shape[0]
    zeros = (df[col] == 0).sum()
    percent = (zeros / total) * 100
    print(f"{col}: Number of zero values = {zeros} out of {total} ({percent:.2f}%)")
# Out:
# Temperature(F): Number of zero values = 2258 out of 6416545 (0.04%)
# Humidity(%): Number of zero values = 0 out of 6416545 (0.00%)
# Wind_Speed(mph): Number of zero values = 0 out of 6416545 (0.00%)
# Visibility(mi): Number of zero values = 6425 out of 6416545 (0.10%)

# %%
df.shape
# Out:
# (6416545, 41)

# %%
df['Duration'] = (df['End_Time'] - df['Start_Time']).dt.total_seconds() / 60
print("Before Filtering:")
print(df['Duration'].describe())
# Out:
# Before Filtering:
# count    6.416545e+06
# mean     4.316153e+02
# std      1.333728e+04
# min      2.000000e+00
# 25%      3.058333e+01
# 50%      7.100000e+01
# 75%      1.233000e+02
# max      2.812939e+06
# Name: Duration, dtype: float64

# %%
max_duration = 720
min_duration = 1
df = df[(df['Duration'] >= min_duration) & (df['Duration'] <= max_duration)]
print("\nAfter Filtering:")
print(df['Duration'].describe())
# Out:
# After Filtering:
# count    6.335828e+06
# mean     1.001624e+02
# std      1.003402e+02
# min      2.000000e+00
# 25%      3.000000e+01
# 50%      6.638333e+01
# 75%      1.217833e+02
# max      7.200000e+02
# Name: Duration, dtype: float64

# %%
df.shape
# Out:
# (6335828, 42)

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
print("Categorical Columns:", categorical_columns)
# Out:
# Categorical Columns: Index(['ID', 'Source', 'Description', 'Street', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Wind_Direction', 'Weather_Condition',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
for col in categorical_columns:
    print(f"\n{col} - Unique Values:")
    print(df[col].value_counts())
# Out:
# ID - Unique Values:
# ID
# A-7777761    1
# A-3          1
# A-4          1
# A-5          1
# A-7777745    1
#             ..
# A-11         1
# A-10         1
# A-9          1
# A-8          1
# A-7          1
# Name: count, Length: 6335828, dtype: int64
#
# Source - Unique Values:
# Source
# Source1    3300995
# Source2    2943889
# Source3      90944
# Name: count, dtype: int64
#
# Description - Unique Values:
# Description
# A crash has occurred causing no to minimum delays. Use caution.                                  6994
# Accident                                                                                         4249
# An unconfirmed report of a crash has been received. Use caution.                                 2738
# A crash has occurred use caution.                                                                2289
# At I-15 - Accident.                                                                              1892
# ...

# %%
missing_values_categorical = df[categorical_columns].isnull().sum()
print("\nMissing Values in Categorical Columns:")
print(missing_values_categorical)
# Out:
# Missing Values in Categorical Columns:
# ID                       0
# Source                   0
# Description              0
# Street                   0
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Wind_Direction           0
# Weather_Condition        0
# Sunrise_Sunset           0
# Civil_Twilight           0
# Nautical_Twilight        0
# Astronomical_Twilight    0
# dtype: int64

# %%
def classify_description(desc):
    if 'accident' in desc.lower():
        return 'Accident'
    elif 'disabled vehicle' in desc.lower():
        return 'Disabled Vehicle'
    elif 'hazard' in desc.lower():
        return 'Hazard'
    else:
        return 'Other'

df['Description'] = df['Description'].apply(classify_description)

# %%
wind_direction_mapping = {
    'N': 'N', 'S': 'S', 'E': 'E', 'W': 'W',
    'CALM': 'No Wind', 'Variable': 'Variable', 'Unknown': 'Unknown'
}

df['Wind_Direction'] = df['Wind_Direction'].replace(wind_direction_mapping)

# %%
import re
import pandas as pd

def clean_street_name(name):
    if pd.isna(name):
        return "Unknown"
    
    name = name.strip().lower()

    if name in ["nan", "NAN", "NaN"]:
        return pd.NA

    name = re.sub(r'^\s*[nswe]\s+|\s+[nswe]\s*$', '', name)
    
    replacements = {
        r'\bst\b': 'street',
        r'\brd\b': 'road',
        r'\bdr\b': 'drive',
        r'\bave\b': 'avenue',
        r'\bblvd\b': 'boulevard',
        r'\bhwy\b': 'highway',
        r'\bln\b': 'lane',
        r'\bct\b': 'court',
        r'\bpkwy\b': 'parkway',
        r'\bsq\b': 'square'
    }
    
    for pattern, repl in replacements.items():
        name = re.sub(pattern, repl, name)
    
    name = re.sub(r'\s+', ' ', name)

    return name.strip()

df['Street'] = df['Street'].replace([None, "", "nan", "NAN", "NaN"], pd.NA)

df['Street'] = df['Street'].str.strip()

df['Street'] = df['Street'].apply(lambda x: clean_street_name(x).strip())

# %%
for col in categorical_columns:
    print(f"\n{col} - Unique Values:")
    print(df[col].value_counts())
# Out:
# ID - Unique Values:
# ID
# A-7777761    1
# A-3          1
# A-4          1
# A-5          1
# A-7777745    1
#             ..
# A-11         1
# A-10         1
# A-9          1
# A-8          1
# A-7          1
# Name: count, Length: 6335828, dtype: int64
#
# Source - Unique Values:
# Source
# Source1    3300995
# Source2    2943889
# Source3      90944
# Name: count, dtype: int64
#
# Description - Unique Values:
# Description
# Accident            4802523
# Other               1522222
# Hazard                 6343
# Disabled Vehicle       4740
# Name: count, dtype: int64
#
# Street - Unique Values:
# Street
# i-95                             140431
# i-5                              109617
# i-10                              98043
# i-80                              70422
# i-75                              56901
#                                   ...
# se booth bend road                    1
# elkhorn estates road                  1
# oleander church road                  1
# ...

# %%
temp = df['Wind_Speed(mph)'].dropna()
Q1 = temp.quantile(0.25)
Q3 = temp.quantile(0.75)
IQR = Q3 - Q1

lower_bound_wind = Q1 - 2 * IQR
upper_bound_wind = Q3 + 2 * IQR

outliers = temp[(temp < lower_bound_wind) | (temp > upper_bound_wind)]
print(f"Number of outliers: {len(outliers)}")
# Out:
# Number of outliers: 183543

# %%
plt.figure(figsize=(12, 6))

# Boxplot
plt.subplot(1, 2, 1)
sns.boxplot(data=df, x='Wind_Speed(mph)')
plt.title('Boxplot of Wind Speed')

# Histogram
plt.subplot(1, 2, 2)
sns.histplot(df['Wind_Speed(mph)'], kde=True, bins=50)
plt.title('Histogram of Wind Speed')

plt.tight_layout()

plt.savefig('E:/accident_severity_analytics/reports/wind_speed_boxplot_histogram.png', dpi=300)

plt.show()

# %%
temp = df['Temperature(F)'].dropna()
Q1 = temp.quantile(0.25)
Q3 = temp.quantile(0.75)
IQR = Q3 - Q1

lower_bound_Temperature = Q1 - 2 * IQR
upper_bound_Temperature = Q3 + 2 * IQR

outliers = temp[(temp < lower_bound_Temperature) | (temp > upper_bound_Temperature)]
print(f"Number of outliers: {len(outliers)}")
# Out:
# Number of outliers: 11343

# %%
plt.figure(figsize=(12, 6))

# Boxplot
plt.subplot(1, 2, 1)
sns.boxplot(data=df, x='Temperature(F)')
plt.title('Boxplot of Temperature')

# Histogram
plt.subplot(1, 2, 2)
sns.histplot(df['Temperature(F)'], kde=True, bins=50)
plt.title('Histogram of Temperature')

plt.tight_layout()

plt.savefig('E:/accident_severity_analytics/reports/Temperature_boxplot_histogram.png', dpi=300)

plt.show()

# %%
df.isnull().sum()
# Out:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# Distance(mi)             0
# Description              0
# Street                   0
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Weather_Timestamp        0
# Temperature(F)           0
# Humidity(%)              0
# Pressure(in)             0
# Visibility(mi)           0
# Wind_Direction           0
# Wind_Speed(mph)          0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# No_Exit                  0
# Railway                  0
# Roundabout               0
# Station                  0
# Stop                     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6335828 entries, 2 to 7728393
# Data columns (total 42 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             datetime64[ns]
#  4   End_Time               datetime64[ns]
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   Distance(mi)           float64
#  8   Description            object
#  9   Street                 object
#  10  City                   object
#  11  County                 object
#  12  State                  object
#  13  Zipcode                object
#  14  Country                object
#  15  Timezone               object
#  16  Weather_Timestamp      datetime64[ns]
#  17  Temperature(F)         float64
#  18  Humidity(%)            float64
#  19  Pressure(in)           float64
#  20  Visibility(mi)         float64
# ...

# %%
df.shape
# Out:
# (6335828, 42)

# %%
df_cleaned = df.reset_index(drop=True)
df_cleaned.to_csv('E:/accident_severity_analytics/data/processed/Cleaned_US_Accidents.csv', index=False)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6335828 entries, 0 to 6335827
# Data columns (total 42 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             datetime64[ns]
#  4   End_Time               datetime64[ns]
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   Distance(mi)           float64
#  8   Description            object
#  9   Street                 object
#  10  City                   object
#  11  County                 object
#  12  State                  object
#  13  Zipcode                object
#  14  Country                object
#  15  Timezone               object
#  16  Weather_Timestamp      datetime64[ns]
#  17  Temperature(F)         float64
#  18  Humidity(%)            float64
#  19  Pressure(in)           float64
#  20  Visibility(mi)         float64
# ...

# %%
df_cleaned.isnull().sum()
# Out:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# Distance(mi)             0
# Description              0
# Street                   0
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Weather_Timestamp        0
# Temperature(F)           0
# Humidity(%)              0
# Pressure(in)             0
# Visibility(mi)           0
# Wind_Direction           0
# Wind_Speed(mph)          0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# No_Exit                  0
# Railway                  0
# Roundabout               0
# Station                  0
# Stop                     0
# ...

# %%
df_cleaned.shape
# Out:
# (6335828, 42)
